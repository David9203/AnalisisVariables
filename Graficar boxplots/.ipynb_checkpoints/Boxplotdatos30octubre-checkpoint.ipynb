# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
from sklearn.preprocessing import StandardScaler
os.getcwd()
# Out:
# '/home/david/Documentos/Analisisdevariables/Graficar boxplots'

# %%
# %cd /home/david/Vídeos
datos = pd.read_csv("Prueba2_5octubre.csv")
datos.head()

datos=datos.drop(datos.index[3453])

datos=datos.drop(datos.index[3719])

datos=datos.drop(datos.index[4390])

datos=datos.drop(datos.index[4405])

datos=datos.drop(datos.index[5441])

datos=datos.drop(datos.index[6156]) #copias de grabaciones
# Out:
# /home/david/Vídeos

# %%
d=datos.iloc[:,1:22]

# %%
x= StandardScaler().fit_transform(d.values)  ##give numpy array values
scalx=pd.DataFrame(x,index=d.index,columns=d.columns) #so we need to transform it 
d=scalx.copy()
scalx.head()
# Out:
#         ACI      NDSI         M       mba       bnf        fm        we  \
# 0 -0.460954 -1.930274  0.093358  0.234185 -0.336028  0.373445  0.424395
# 1 -0.358760 -1.704739  0.101038  0.614815 -0.335453  0.155490  0.518452
# 2 -0.168540 -1.699262  0.099094  0.167989 -0.338223  0.077841  0.594225
# 3 -0.530193 -1.538603  0.099122  0.118341 -0.336347  0.517923  0.408786
# 4 -0.342901 -1.614396  0.103346  0.217636 -0.337678  0.343179  0.487339
#
#         rms        cf     ADIm1  ...     ADIm3     ADIm4     ADIm5     ADIm6  \
# 0  0.079169 -0.364132  0.611941  ...  0.739579  0.868605  0.733324  0.446050
# 1  0.086838 -0.363665  0.298114  ...  0.145735  0.346014  0.307790  0.618720
# 2  0.084763 -0.360494  0.709224  ...  0.437480  0.144819  0.496995  0.468328
# 3  0.084265 -0.364142  0.579916  ...  0.731900  0.815949  0.856067  0.913654
# 4  0.089769 -0.355943  0.422338  ...  0.108257 -0.122154 -0.164984  0.191101
#
#       ADIm7     ADIm8     ADIm9    ADIm10    ADIm11       PSD
# ...

# %%
df=scalx.copy()
def remove_outlier(df_in, col_name):
    q1 = df_in[col_name].quantile(0.25)
    q3 = df_in[col_name].quantile(0.75)
    iqr = q3-q1 #Interquartile range
    fence_low  = q1-1.5*iqr
    fence_high = q3+1.5*iqr
    df_out = df_in.loc[(df_in[col_name] > fence_low) & (df_in[col_name] < fence_high)]
    return df_out

# %%
df.describe()
# Out:
#                 ACI          NDSI             M           mba           bnf  \
# count  1.836500e+04  1.836500e+04  1.836500e+04  1.836500e+04  1.836500e+04
# mean   5.033346e-15 -4.669163e-16 -1.648438e-16  1.887343e-15 -1.145588e-16
# std    1.000027e+00  1.000027e+00  1.000027e+00  1.000027e+00  1.000027e+00
# min   -3.277784e+01 -2.813938e+00 -1.221903e+00 -1.023549e+00 -3.680997e-01
# 25%   -4.042109e-01 -8.185439e-01 -6.760379e-01 -8.580578e-01 -3.196584e-01
# 50%   -1.402926e-01  2.943619e-01  1.058066e-01 -4.608786e-01 -2.743293e-01
# 75%    2.910852e-01  9.361166e-01  1.224961e-01  9.126996e-01 -1.711276e-01
# max    1.504104e+01  1.074784e+00  4.760827e+01  1.673960e+00  5.956378e+01
#
#                  fm            we           rms            cf         ADIm1  \
# count  1.836500e+04  1.836500e+04  1.836500e+04  1.836500e+04  1.836500e+04
# mean   7.073816e-15  5.855093e-16  2.856474e-16 -6.296080e-16  6.298725e-16
# ...

# %%
datos['Transformacion'].value_counts().plot(kind='bar')

# %%
scalx.columns
scalx.columns[0]
# Out:
# 'ACI'

# %%
a=remove_outlier(df,scalx.columns[0])
a=remove_outlier(a, scalx.columns[1])
a=remove_outlier(a, scalx.columns[2])
a=remove_outlier(a, scalx.columns[3])
a=remove_outlier(a, scalx.columns[4])
a=remove_outlier(a, scalx.columns[5])
a=remove_outlier(a, scalx.columns[6])
a=remove_outlier(a, scalx.columns[7])
a=remove_outlier(a, scalx.columns[8])
a=remove_outlier(a, scalx.columns[9])
a=remove_outlier(a, scalx.columns[10])
a=remove_outlier(a, scalx.columns[11])
a=remove_outlier(a, scalx.columns[12])
a=remove_outlier(a, scalx.columns[13])
a=remove_outlier(a, scalx.columns[14])
a=remove_outlier(a, scalx.columns[15])
a=remove_outlier(a, scalx.columns[16])
a=remove_outlier(a, scalx.columns[17])
a=remove_outlier(a, scalx.columns[18])
a=remove_outlier(a, scalx.columns[19])
a=remove_outlier(a, scalx.columns[20])

# %%
scalxlabel=a
scalxlabel['label']= datos.Transformacion
fig=scalxlabel.boxplot(figsize = (18,18),by='label')

# %%
scalxlabel['hora'] = datos['filename'].str.slice(-10,-8)
scalxlabel.head()
# Out:
#         ACI      NDSI         M       mba       bnf        fm        we  \
# 0 -0.460954 -1.930274  0.093358  0.234185 -0.336028  0.373445  0.424395
# 1 -0.358760 -1.704739  0.101038  0.614815 -0.335453  0.155490  0.518452
# 3 -0.530193 -1.538603  0.099122  0.118341 -0.336347  0.517923  0.408786
# 4 -0.342901 -1.614396  0.103346  0.217636 -0.337678  0.343179  0.487339
# 6 -0.488006 -1.523945  0.108790  0.085243 -0.336795  0.460566  0.403508
#
#         rms        cf     ADIm1  ...     ADIm5     ADIm6     ADIm7     ADIm8  \
# 0  0.079169 -0.364132  0.611941  ...  0.733324  0.446050  0.847307  0.292161
# 1  0.086838 -0.363665  0.298114  ...  0.307790  0.618720  0.757360  0.199186
# 3  0.084265 -0.364142  0.579916  ...  0.856067  0.913654  0.916360  0.305257
# 4  0.089769 -0.355943  0.422338  ... -0.164984  0.191101  0.788239  0.348231
# 6  0.094493 -0.363559  0.620948  ...  0.785066  0.940346  1.092106  0.456711
#
#       ADIm9    ADIm10    ADIm11       PSD  label  hora
# ...

# %%
scals=scalxlabel.sort_values(by="hora")

# %%
sns.set(rc={'figure.figsize':(20,20)})

ax = sns.boxplot(x="label", y="ACI", hue="hora", data=scals, palette="Set3")

# %%
sns.set(rc={'figure.figsize':(20,20)})

ax = sns.boxplot(x="label", y="NDSI", hue="hora", data=scals, palette="Set3")

# %%
sns.set(rc={'figure.figsize':(20,20)})

ax = sns.boxplot(x="label", y="PSD", hue="hora", data=scals, palette="Set3")

# %%
sns.set(rc={'figure.figsize':(20,20)})

ax = sns.boxplot(x="label", y="we", hue="hora", data=scals, palette="Set3")

# %%
scalxlabel['etapa'] = datos['filename'].str.slice(-10,-8).astype(int).apply(lambda x: 'e1' if 4<= x < 8 else ('e2' if 8< x < 16 else ('e3' if 16< x < 20 else 'e4')))

# %%
scals=scalxlabel.sort_values(by="hora")
ax = sns.boxplot(x="label", y="we", hue="etapa", data=scals, palette="Set3")

# %%
scals.to_csv('filt.csv')

# %%
scals=scalxlabel.sort_values(by="hora")
ax = sns.boxplot(x="label", y="PSD", hue="etapa", data=scals, palette="Set3")

# %%
datos.columns
# Out:
# Index(['filename', 'ACI', 'NDSI', 'M', 'mba', 'bnf', 'fm', 'we', 'rms', 'cf',
#        'ADIm1', 'ADIm2', 'ADIm3', 'ADIm4', 'ADIm5', 'ADIm6', 'ADIm7', 'ADIm8',
#        'ADIm9', 'ADIm10', 'ADIm11', 'PSD', 'Transformacion'],
#       dtype='object')

# %%
fig = plt.figure()
ax1 = fig.add_subplot(311)
ax2 = fig.add_subplot(312)
ax3 = fig.add_subplot(313)
var='M'
var3='rms'
var2='ACI'
sns.boxplot(x="label", y=var, hue="hora", data=scalxlabel, palette="Set3",ax=ax1)
sns.boxplot(x="label", y=var3, hue="hora", data=scalxlabel, palette="Set3",ax=ax2)
sns.boxplot(x="label", y=var2, hue="hora", data=scalxlabel, palette="Set3",ax=ax3)

# %%
scalxlabel.head()
# Out:
#         ACI      NDSI         M       mba        fm        we       rms  \
# 0 -0.460954 -1.930274  0.093358  0.234185  0.373445  0.424395  0.079169
# 1 -0.358760 -1.704739  0.101038  0.614815  0.155490  0.518452  0.086838
# 3 -0.530193 -1.538603  0.099122  0.118341  0.517923  0.408786  0.084265
# 4 -0.342901 -1.614396  0.103346  0.217636  0.343179  0.487339  0.089769
# 6 -0.488006 -1.523945  0.108790  0.085243  0.460566  0.403508  0.094493
#
#       ADIm1     ADIm2     ADIm3     ADIm4     ADIm5     ADIm6     ADIm7  \
# 0  0.611941  0.695026  0.739579  0.868605  0.733324  0.446050  0.847307
# 1  0.298114  0.584963  0.145735  0.346014  0.307790  0.618720  0.757360
# 3  0.579916  0.567002  0.731900  0.815949  0.856067  0.913654  0.916360
# 4  0.422338  0.266979  0.108257 -0.122154 -0.164984  0.191101  0.788239
# 6  0.620948  0.593450  0.569288  0.623757  0.785066  0.940346  1.092106
#
#       ADIm8     ADIm9  label hora etapa
# 0  0.292161  0.112907      0   11    e2
# ...

# %%
fig = plt.figure()
ax1 = fig.add_subplot(311)
ax2 = fig.add_subplot(312)
ax3 = fig.add_subplot(313)
var2='rms'
var1='NDSI'
var='ACI'
etapa='etapa'
sns.boxplot(x="label", y=var, hue=etapa, data=scalxlabel, palette="Set3",ax=ax1)
sns.boxplot(x="label", y=var1, hue=etapa, data=scalxlabel, palette="Set3",ax=ax2)
sns.boxplot(x="label", y=var2, hue=etapa, data=scalxlabel, palette="Set3",ax=ax3)

# %%
fig = plt.figure()
ax1 = fig.add_subplot(311)
ax2 = fig.add_subplot(312)
ax3 = fig.add_subplot(313)
var2='mba'
var1='NDSI'
var='ACI'
etapa='etapa'
sns.boxplot(x="label", y=var, hue=etapa, data=scalxlabel, palette="Set3",ax=ax1)
sns.boxplot(x="label", y=var1, hue=etapa, data=scalxlabel, palette="Set3",ax=ax2)
sns.boxplot(x="label", y=var2, hue=etapa, data=scalxlabel, palette="Set3",ax=ax3)

# %%
'''filename', 'ACI', 'NDSI', 'M', 'mba', 'bnf', 'fm', 'we', 'rms', 'cf',
       'ADIm1', 'ADIm2', 'ADIm3', 'ADIm4', 'ADIm5', 'ADIm6', 'ADIm7', 'ADIm8',
       'ADIm9', 'ADIm10', 'ADIm11', 'PSD'''

fig = plt.figure()
ax1 = fig.add_subplot(311)
ax2 = fig.add_subplot(312)
ax3 = fig.add_subplot(313)
var2='bnf'
var1='fm'
var='we'
etapa='etapa'
sns.boxplot(x="label", y=var, hue=etapa, data=scalxlabel, palette="Set3",ax=ax1)
sns.boxplot(x="label", y=var1, hue=etapa, data=scalxlabel, palette="Set3",ax=ax2)
sns.boxplot(x="label", y=var2, hue=etapa, data=scalxlabel, palette="Set3",ax=ax3)

# %%
'''filename', 'ACI', 'NDSI', 'M', 'mba', 'bnf', 'fm', 'we', 'rms', 'cf',
       'ADIm1', 'ADIm2', 'ADIm3', 'ADIm4', 'ADIm5', 'ADIm6', 'ADIm7', 'ADIm8',
       'ADIm9', 'ADIm10', 'ADIm11', 'PSD'''

fig = plt.figure()
ax1 = fig.add_subplot(311)
ax2 = fig.add_subplot(312)
ax3 = fig.add_subplot(313)
var2='cf'
var1='ADIm1'
var='PSD'
etapa='etapa'
sns.boxplot(x="label", y=var, hue=etapa, data=scalxlabel, palette="Set3",ax=ax1)
sns.boxplot(x="label", y=var1, hue=etapa, data=scalxlabel, palette="Set3",ax=ax2)
sns.boxplot(x="label", y=var2, hue=etapa, data=scalxlabel, palette="Set3",ax=ax3)

# %%
'''filename', 'ACI', 'NDSI', 'M', 'mba', 'bnf', 'fm', 'we', 'rms', 'cf',
       'ADIm1', 'ADIm2', 'ADIm3', 'ADIm4', 'ADIm5', 'ADIm6', 'ADIm7', 'ADIm8',
       'ADIm9', 'ADIm10', 'ADIm11', 'PSD'''

fig = plt.figure()
ax1 = fig.add_subplot(311)
ax2 = fig.add_subplot(312)
ax3 = fig.add_subplot(313)
var2='ADIm1'
var1='ADIm2'
var='ADIm3'
etapa='etapa'
sns.boxplot(x="label", y=var, hue=etapa, data=scalxlabel, palette="Set3",ax=ax1)
sns.boxplot(x="label", y=var1, hue=etapa, data=scalxlabel, palette="Set3",ax=ax2)
sns.boxplot(x="label", y=var2, hue=etapa, data=scalxlabel, palette="Set3",ax=ax3)

# %%
'''filename', 'ACI', 'NDSI', 'M', 'mba', 'bnf', 'fm', 'we', 'rms', 'cf',
       'ADIm1', 'ADIm2', 'ADIm3', 'ADIm4', 'ADIm5', 'ADIm6', 'ADIm7', 'ADIm8',
       'ADIm9', 'ADIm10', 'ADIm11', 'PSD'''

fig = plt.figure()
ax1 = fig.add_subplot(311)
ax2 = fig.add_subplot(312)
ax3 = fig.add_subplot(313)
var2='ADIm4'
var1='ADIm5'
var='ADIm6'
etapa='etapa'
sns.boxplot(x="label", y=var, hue=etapa, data=scalxlabel, palette="Set3",ax=ax1)
sns.boxplot(x="label", y=var1, hue=etapa, data=scalxlabel, palette="Set3",ax=ax2)
sns.boxplot(x="label", y=var2, hue=etapa, data=scalxlabel, palette="Set3",ax=ax3)

# %%
'''filename', 'ACI', 'NDSI', 'M', 'mba', 'bnf', 'fm', 'we', 'rms', 'cf',
       'ADIm1', 'ADIm2', 'ADIm3', 'ADIm4', 'ADIm5', 'ADIm6', 'ADIm7', 'ADIm8',
       'ADIm9', 'ADIm10', 'ADIm11', 'PSD'''

fig = plt.figure()
ax1 = fig.add_subplot(311)
ax2 = fig.add_subplot(312)
ax3 = fig.add_subplot(313)
var2='ADIm11'
var1='ADIm10'
var='ADIm9'
etapa='etapa'
sns.boxplot(x="label", y=var, hue=etapa, data=scalxlabel, palette="Set3",ax=ax1)
sns.boxplot(x="label", y=var1, hue=etapa, data=scalxlabel, palette="Set3",ax=ax2)
sns.boxplot(x="label", y=var2, hue=etapa, data=scalxlabel, palette="Set3",ax=ax3)

# %%
trans={'Alta':2,'Baja':0,'Media':1}
ypruebaP=[trans[item] for item in scalxlabel["label"]]
scalxlabel["label"]=ypruebaP

# %%
scalxlabel=scalxlabel.drop(['bnf', 'PSD','cf','ADIm10','ADIm11'], axis=1)
scalxlabel.head()
# Out:
#         ACI      NDSI         M       mba        fm        we       rms  \
# 0 -0.460954 -1.930274  0.093358  0.234185  0.373445  0.424395  0.079169
# 1 -0.358760 -1.704739  0.101038  0.614815  0.155490  0.518452  0.086838
# 3 -0.530193 -1.538603  0.099122  0.118341  0.517923  0.408786  0.084265
# 4 -0.342901 -1.614396  0.103346  0.217636  0.343179  0.487339  0.089769
# 6 -0.488006 -1.523945  0.108790  0.085243  0.460566  0.403508  0.094493
#
#       ADIm1     ADIm2     ADIm3     ADIm4     ADIm5     ADIm6     ADIm7  \
# 0  0.611941  0.695026  0.739579  0.868605  0.733324  0.446050  0.847307
# 1  0.298114  0.584963  0.145735  0.346014  0.307790  0.618720  0.757360
# 3  0.579916  0.567002  0.731900  0.815949  0.856067  0.913654  0.916360
# 4  0.422338  0.266979  0.108257 -0.122154 -0.164984  0.191101  0.788239
# 6  0.620948  0.593450  0.569288  0.623757  0.785066  0.940346  1.092106
#
#       ADIm8     ADIm9  label hora etapa
# 0  0.292161  0.112907      0   11    e2
# ...

# %%
dfe1=scalxlabel.loc[scalxlabel['etapa'] == "e1"]
dfe2=scalxlabel.loc[scalxlabel['etapa'] == "e2"]
dfe3=scalxlabel.loc[scalxlabel['etapa'] == "e3"]
dfe4=scalxlabel.loc[scalxlabel['etapa'] == "e4"]
dfe1.iloc[:,0:16].head()
# Out:
#          ACI      NDSI         M       mba        fm        we       rms  \
# 28 -0.034393 -1.461197  0.116904 -0.146445 -0.488993  0.403580  0.104702
# 35 -0.323724 -0.626878  0.119636 -0.295387  0.121013  0.178613  0.106338
# 36 -0.055047  0.095421  0.115113 -0.295387 -0.462682 -0.035225  0.102152
# 37 -0.316640 -0.274459  0.111068 -0.229191  0.146205  0.074833  0.097457
# 38 -0.288557 -0.056579  0.112684 -0.245740  0.175199 -0.100075  0.099351
#
#        ADIm1     ADIm2     ADIm3     ADIm4     ADIm5     ADIm6     ADIm7  \
# 28  0.328859  0.548032  0.282325  0.227336  0.264159 -0.185445  0.156478
# 35  0.049346  0.533784  0.425584  0.001301  0.429808  0.385883  0.736159
# 36  0.683522  0.657540  0.652370 -0.577418  0.474697  0.329671  0.522053
# 37  0.001336  0.226627  0.405258  0.094518  0.523624 -0.187888  0.800642
# 38 -0.201621  0.199384  0.745685 -0.223115  0.523981 -0.192465  0.798960
#
#        ADIm8     ADIm9
# 28 -0.122143  0.262660
# 35  1.168159  0.493590
# ...

# %% [markdown]
# # Entrenando con etapa 1

# %%
X_train1.iloc[:,0:16].head()
# Out:
#            ACI      NDSI         M       mba        fm        we       rms  \
# 8797 -0.248643  0.976822 -0.683028 -0.758763  0.481552 -0.842328 -0.740543
# 1753 -0.178724 -1.218725  0.103791 -0.229191  0.082474  0.184388  0.090338
# 2620  0.005386 -1.241757  0.110900 -0.113347 -0.386564  0.367742  0.097157
# 613  -0.382429 -1.081940  0.116555 -0.444329  0.192735  0.250599  0.102258
# 615  -0.191091 -0.339164  0.116575 -0.444329 -0.012459 -0.160089  0.103635
#
#          ADIm1     ADIm2     ADIm3     ADIm4     ADIm5     ADIm6     ADIm7  \
# 8797  0.257582  0.380441  0.877341 -0.107530  0.391507  0.564721 -0.037989
# 1753  0.426307  0.269302  0.089512  0.112173  0.114405  0.195506 -0.649084
# 2620  0.117576  0.299851 -0.410001 -0.239503 -0.150762 -0.040029 -0.792112
# 613   0.405292  0.471277  0.361162  0.450534  0.496501  0.332138  1.083023
# 615   0.197103  0.829783  0.409562  0.428332  0.349093  0.243876  1.191658
#
#          ADIm8     ADIm9
# 8797  0.649151  0.021677
# ...

# %%
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt

X_train1, X_test1, y_train1, y_test1 = train_test_split(dfe1.iloc[:,0:22], dfe1["label"], test_size=0.2)
X_train1=X_train1.sort_values(by='label')
y_train1=y_train1.sort_values()

##con permanencia 
from hmmlearn import hmm

dataprofe=X_train1.iloc[:,0:16]
X_test1=X_test1.iloc[:,0:16]

modelhm=hmm.GMMHMM(n_components=8,n_mix=3,covariance_type="spherical") 
modelhm.fit(dataprofe)
labels = modelhm.predict(dataprofe)
#        gmm = GMM(n_components=j).fit(principalf)
#       labels = gmm.predict(principalf)


fig = plt.figure(figsize=(15,15))
ax = fig.add_subplot(2,2,1)
x=np.arange(dataprofe.shape[0])

img = ax.scatter(x,y_train1, c=y_train1, cmap=plt.viridis())
axx = fig.add_subplot(2,2,3)
img = axx.scatter(x, labels, c=labels, cmap=plt.viridis())
plt.show()

# %%
from sklearn.metrics import accuracy_score

newlist = []

for item in labels:
    #print(item)
    if item == 0  :
        item = 1
    elif item == 1  :
        item = 2
    elif item == 2  :
        item = 0
    elif item == 3  :
        item = 2
    elif item == 4  :
        item = 1
    elif item == 5  :
        item = 0    
    elif item == 6  :
        item = 0
    elif item == 7  :
        item = 1
        #print(item)
    newlist.append(item)
newlist;
print(accuracy_score(y_train1,newlist))
# Out:
# 0.7343096234309623

# %%
labels = modelhm.predict(X_test1)
from sklearn.metrics import accuracy_score

newlist = []

for item in labels:
    #print(item)
    if item == 0  :
        item = 1
    elif item == 1  :
        item = 2
    elif item == 2  :
        item = 0
    elif item == 3  :
        item = 2
    elif item == 4  :
        item = 1
    elif item == 5  :
        item = 0    
    elif item == 6  :
        item = 0
    elif item == 7  :
        item = 1
        #print(item)
    newlist.append(item)
newlist;
print(accuracy_score(y_test1,newlist))
# Out:
# 0.7041666666666667

# %% [markdown]
# # etapa 2

# %%
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt

X_train1, X_test1, y_train1, y_test1 = train_test_split(dfe2.iloc[:,0:22], dfe2["label"], test_size=0.2)
X_train1=X_train1.sort_values(by='label')
y_train1=y_train1.sort_values()

##con permanencia 
from hmmlearn import hmm

dataprofe=X_train1.iloc[:,0:16]
X_test1=X_test1.iloc[:,0:16]

modelhm=hmm.GMMHMM(n_components=8,n_mix=3,covariance_type="spherical") 
modelhm.fit(dataprofe)
labels = modelhm.predict(dataprofe)
#        gmm = GMM(n_components=j).fit(principalf)
#       labels = gmm.predict(principalf)


fig = plt.figure(figsize=(15,15))
ax = fig.add_subplot(2,2,1)
x=np.arange(dataprofe.shape[0])

img = ax.scatter(x,y_train1, c=y_train1, cmap=plt.viridis())
axx = fig.add_subplot(2,2,3)
img = axx.scatter(x, labels, c=labels, cmap=plt.viridis())
plt.show()

# %%
from sklearn.metrics import accuracy_score

newlist = []

for item in labels:
    #print(item)
    if item == 0  :
        item = 0
    elif item == 1  :
        item = 1
    elif item == 2  :
        item = 0
    elif item == 3  :
        item = 1
    elif item == 4  :
        item = 0
    elif item == 5  :
        item = 0    
    elif item == 6  :
        item = 0
    elif item == 7  :
        item = 2
        #print(item)
    newlist.append(item)
newlist;
print(accuracy_score(y_train1,newlist))
# Out:
# 0.9487847222222222

# %%
labels = modelhm.predict(X_test1)

from sklearn.metrics import accuracy_score

newlist = []

for item in labels:
    #print(item)
    if item == 0  :
        item = 0
    elif item == 1  :
        item = 1
    elif item == 2  :
        item = 0
    elif item == 3  :
        item = 1
    elif item == 4  :
        item = 0
    elif item == 5  :
        item = 0    
    elif item == 6  :
        item = 0
    elif item == 7  :
        item = 2
        #print(item)
    newlist.append(item)
newlist;
print(accuracy_score(y_test1,newlist))
# Out:
# 0.8339100346020761

# %% [markdown]
# # ETAPA 3

# %%
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt

X_train1, X_test1, y_train1, y_test1 = train_test_split(dfe3.iloc[:,0:22], dfe3["label"], test_size=0.2)
X_train1=X_train1.sort_values(by='label')
y_train1=y_train1.sort_values()

##con permanencia 
from hmmlearn import hmm

dataprofe=X_train1.iloc[:,0:16]
X_test1=X_test1.iloc[:,0:16]

modelhm=hmm.GMMHMM(n_components=8,n_mix=3,covariance_type="spherical") 
modelhm.fit(dataprofe)
labels = modelhm.predict(dataprofe)
#        gmm = GMM(n_components=j).fit(principalf)
#       labels = gmm.predict(principalf)


fig = plt.figure(figsize=(15,15))
ax = fig.add_subplot(2,2,1)
x=np.arange(dataprofe.shape[0])

img = ax.scatter(x,y_train1, c=y_train1, cmap=plt.viridis())
axx = fig.add_subplot(2,2,3)
img = axx.scatter(x, labels, c=labels, cmap=plt.viridis())
plt.show()

# %%
from sklearn.metrics import accuracy_score

newlist = []

for item in labels:
    #print(item)
    if item == 0  :
        item = 1
    elif item == 1  :
        item = 0
    elif item == 2  :
        item = 1
    elif item == 3  :
        item = 0
    elif item == 4  :
        item = 0
    elif item == 5  :
        item = 2    
    elif item == 6  :
        item = 0
    elif item == 7  :
        item = 1
        #print(item)
    newlist.append(item)
newlist;
print(accuracy_score(y_train1,newlist))
# Out:
# 0.8663522012578616

# %%
labels = modelhm.predict(X_test1)

from sklearn.metrics import accuracy_score

newlist = []

for item in labels:
    #print(item)
    if item == 0  :
        item = 1
    elif item == 1  :
        item = 0
    elif item == 2  :
        item = 1
    elif item == 3  :
        item = 0
    elif item == 4  :
        item = 0
    elif item == 5  :
        item = 2    
    elif item == 6  :
        item = 0
    elif item == 7  :
        item = 1
        #print(item)
    newlist.append(item)
newlist;
print(accuracy_score(y_test1,newlist))
# Out:
# 0.8238993710691824

# %% [markdown]
# # ETAPA 4

# %%
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt

X_train1, X_test1, y_train1, y_test1 = train_test_split(dfe4.iloc[:,0:22], dfe4["label"], test_size=0.2)
X_train1=X_train1.sort_values(by='label')
y_train1=y_train1.sort_values()

##con permanencia 
from hmmlearn import hmm

dataprofe=X_train1.iloc[:,0:16]
X_test1=X_test1.iloc[:,0:16]

modelhm=hmm.GMMHMM(n_components=8,n_mix=3,covariance_type="spherical") 
modelhm.fit(dataprofe)
labels = modelhm.predict(dataprofe)
#        gmm = GMM(n_components=j).fit(principalf)
#       labels = gmm.predict(principalf)


fig = plt.figure(figsize=(15,15))
ax = fig.add_subplot(2,2,1)
x=np.arange(dataprofe.shape[0])

img = ax.scatter(x,y_train1, c=y_train1, cmap=plt.viridis())
axx = fig.add_subplot(2,2,3)
img = axx.scatter(x, labels, c=labels, cmap=plt.viridis())
plt.show()

# %%
from sklearn.metrics import accuracy_score

newlist = []

for item in labels:
    #print(item)
    if item == 0  :
        item = 1
    elif item == 1  :
        item = 0
    elif item == 2  :
        item = 1
    elif item == 3  :
        item = 1
    elif item == 4  :
        item = 2
    elif item == 5  :
        item = 0    
    elif item == 6  :
        item = 0
    elif item == 7  :
        item = 1
        #print(item)
    newlist.append(item)
newlist;
print(accuracy_score(y_train1,newlist))
# Out:
# 0.7097151775263363

# %%
labels = modelhm.predict(X_test1)

from sklearn.metrics import accuracy_score

newlist = []

for item in labels:
    #print(item)
    if item == 0  :
        item = 1
    elif item == 1  :
        item = 0
    elif item == 2  :
        item = 1
    elif item == 3  :
        item = 1
    elif item == 4  :
        item = 2
    elif item == 5  :
        item = 0    
    elif item == 6  :
        item = 0
    elif item == 7  :
        item = 1
        #print(item)
    newlist.append(item)
newlist;
print(accuracy_score(y_test1,newlist))
# Out:
# 0.6911076443057722

# %%
scalxlabel.head()
# Out:
#         ACI      NDSI         M       mba        fm        we       rms  \
# 0 -0.460954 -1.930274  0.093358  0.234185  0.373445  0.424395  0.079169
# 1 -0.358760 -1.704739  0.101038  0.614815  0.155490  0.518452  0.086838
# 3 -0.530193 -1.538603  0.099122  0.118341  0.517923  0.408786  0.084265
# 4 -0.342901 -1.614396  0.103346  0.217636  0.343179  0.487339  0.089769
# 6 -0.488006 -1.523945  0.108790  0.085243  0.460566  0.403508  0.094493
#
#       ADIm1     ADIm2     ADIm3     ADIm4     ADIm5     ADIm6     ADIm7  \
# 0  0.611941  0.695026  0.739579  0.868605  0.733324  0.446050  0.847307
# 1  0.298114  0.584963  0.145735  0.346014  0.307790  0.618720  0.757360
# 3  0.579916  0.567002  0.731900  0.815949  0.856067  0.913654  0.916360
# 4  0.422338  0.266979  0.108257 -0.122154 -0.164984  0.191101  0.788239
# 6  0.620948  0.593450  0.569288  0.623757  0.785066  0.940346  1.092106
#
#       ADIm8     ADIm9  label hora etapa
# 0  0.292161  0.112907      0   11    e2
# ...

# %% [markdown]
# # Para a siguiente prueba se quitan las variables que cambian en las etapas, con la razon de que los indices no cambien durante el dia

# %%
df=scalxlabel.copy()
df1 = df[['ACI','rms','fm','ADIm1','ADIm1','ADIm2','ADIm3','ADIm4','ADIm5','ADIm6','ADIm7','ADIm8','ADIm9','label','hora','etapa']]
df.head()
# Out:
#         ACI      NDSI         M       mba        fm        we       rms  \
# 0 -0.460954 -1.930274  0.093358  0.234185  0.373445  0.424395  0.079169
# 1 -0.358760 -1.704739  0.101038  0.614815  0.155490  0.518452  0.086838
# 3 -0.530193 -1.538603  0.099122  0.118341  0.517923  0.408786  0.084265
# 4 -0.342901 -1.614396  0.103346  0.217636  0.343179  0.487339  0.089769
# 6 -0.488006 -1.523945  0.108790  0.085243  0.460566  0.403508  0.094493
#
#       ADIm1     ADIm2     ADIm3     ADIm4     ADIm5     ADIm6     ADIm7  \
# 0  0.611941  0.695026  0.739579  0.868605  0.733324  0.446050  0.847307
# 1  0.298114  0.584963  0.145735  0.346014  0.307790  0.618720  0.757360
# 3  0.579916  0.567002  0.731900  0.815949  0.856067  0.913654  0.916360
# 4  0.422338  0.266979  0.108257 -0.122154 -0.164984  0.191101  0.788239
# 6  0.620948  0.593450  0.569288  0.623757  0.785066  0.940346  1.092106
#
#       ADIm8     ADIm9  label hora etapa
# 0  0.292161  0.112907      0   11    e2
# ...

# %%
df.iloc[:,0:16].head()
df=df.sort_values(by='label')

# %%
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt

X_train1, X_test1, y_train1, y_test1 = train_test_split(df, df["label"], test_size=0.2)
X_train1=X_train1.sort_values(by='label')
y_train1=y_train1.sort_values()

##con permanencia 
from hmmlearn import hmm

dataprofe=X_train1.iloc[:,0:16]
X_test1=X_test1.iloc[:,0:16]

modelhm=hmm.GMMHMM(n_components=8,n_mix=3,covariance_type="spherical") 
modelhm.fit(dataprofe)
labels = modelhm.predict(dataprofe)
#        gmm = GMM(n_components=j).fit(principalf)
#       labels = gmm.predict(principalf)


fig = plt.figure(figsize=(15,15))
ax = fig.add_subplot(2,2,1)
x=np.arange(dataprofe.shape[0])

img = ax.scatter(x,y_train1, c=y_train1, cmap=plt.viridis())
axx = fig.add_subplot(2,2,3)
img = axx.scatter(x, labels, c=labels, cmap=plt.viridis())
plt.show()

# %%
from sklearn.metrics import accuracy_score

newlist = []

for item in labels:
    #print(item)
    if item == 0  :
        item = 0
    elif item == 1  :
        item = 0
    elif item == 2  :
        item = 1
    elif item == 3  :
        item = 1
    elif item == 4  :
        item = 0
    elif item == 5  :
        item = 0    
    elif item == 6  :
        item = 1
    elif item == 7  :
        item = 0
        #print(item)
    newlist.append(item)
newlist;
print(accuracy_score(y_train1,newlist))
# Out:
# 0.7025244913338358

# %% [markdown]
# EN ESTE NOTEBOOK:
#
# Se busca realizar el clustering de guajira y bolivar por medio del clasificador GMMMHMM,

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
from sklearn.preprocessing import StandardScaler
os.getcwd()
# Out:
# '/home/david/Documentos/Analisisdevariables/paraescogerlosdias'

# %%
dGuajira = pd.read_csv("/home/david/Documentos/Analisisdevariables/Datospuros/DatosGuajira.csv")
d.head()
# Out:
#    Unnamed: 0    Lugar Grabadora Transformación Permanencia      Longitud  \
# 0    20160101  Guajira      5067           Alta        Baja  73º26'3.2''W
# 1    20160102  Guajira      5067           Alta        Baja  73º26'3.2''W
# 2    20160103  Guajira      5067           Alta        Baja  73º26'3.2''W
# 3    20160104  Guajira      5067           Alta        Baja  73º26'3.2''W
# 4    20160105  Guajira      5067           Alta        Baja  73º26'3.2''W
#
#       ACIft       ADI     ACItf        BI  ...     ADIm2     ADIm3     ADIm4  \
# 0 -0.171947  0.584782 -0.475717 -0.860168  ...  0.206630  0.260610 -0.326033
# 1 -0.304241  0.874729 -0.565690 -0.375552  ...  0.350874  0.122914 -0.517690
# 2 -0.339822  0.746814 -0.458379 -0.135205  ...  0.290717  0.507416 -0.391097
# 3 -0.229584  0.918072 -0.325400 -0.110043  ...  0.350568  0.274446 -0.362861
# 4 -0.308185  0.817189 -0.322157 -0.138337  ...  0.240093  0.233373 -0.323291
#
# ...

# %%
dBolivar = pd.read_csv("/home/david/Documentos/Analisisdevariables/Datospuros/DatosBolivar.csv")
d.head()
# Out:
#    Unnamed: 0    Lugar Grabadora Transformación Permanencia      Longitud  \
# 0    20160101  Guajira      5067           Alta        Baja  73º26'3.2''W
# 1    20160102  Guajira      5067           Alta        Baja  73º26'3.2''W
# 2    20160103  Guajira      5067           Alta        Baja  73º26'3.2''W
# 3    20160104  Guajira      5067           Alta        Baja  73º26'3.2''W
# 4    20160105  Guajira      5067           Alta        Baja  73º26'3.2''W
#
#       ACIft       ADI     ACItf        BI  ...     ADIm2     ADIm3     ADIm4  \
# 0 -0.171947  0.584782 -0.475717 -0.860168  ...  0.206630  0.260610 -0.326033
# 1 -0.304241  0.874729 -0.565690 -0.375552  ...  0.350874  0.122914 -0.517690
# 2 -0.339822  0.746814 -0.458379 -0.135205  ...  0.290717  0.507416 -0.391097
# 3 -0.229584  0.918072 -0.325400 -0.110043  ...  0.350568  0.274446 -0.362861
# 4 -0.308185  0.817189 -0.322157 -0.138337  ...  0.240093  0.233373 -0.323291
#
# ...

# %%
#En MetaBolivar se encuentran los datos que no son las variables como la grabadora el dia etc 
MetaBolivar=dBolivar.iloc[:,1:7].copy()
dBolivar.drop(dBolivar.iloc[:, 0:7], inplace = True, axis = 1) 
dBolivar.head()
# Out:
#                ACIft               ADI              ACItf                 BI  \
# 0  0,881962198755385  1,37958537980212  0,686408536249901  0,373568767132005
# 1   1,02242344541564  1,61360991490528   1,37875426585608  0,689790500722663
# 2   1,11116104095815  1,28233317737695   1,50181287223534  0,635879208560468
# 3   1,66804956507168  1,37101511856645    1,6270492115321    1,0265697634148
# 4   1,35759805586675  1,47356517662983    1,2911463575993  0,762732894091573
#
#                   TE                 ESM               NDSI  \
# 0  0,780667110192611  -0,995663533743657  0,102276753677763
# 1  0,740970925232941  -0,858666168317373    0,2724419033052
# 2  0,750586921433434   -1,35990323841196  0,467130123147461
# 3  0,600144118586274   -1,69252968160614  0,609323299525549
# 4  0,703073142191573   -1,25572078131366  0,266255540162315
#
#                     P                  M                  NP  ...  \
# 0  -0,442451947292613  0,138899511739008  -0,164821476793662  ...
# ...

# %%
#En yprueba se encuentra las variab
ypruebaT=MetaBolivar["Transformación"]
trans={'Alta':2,'Baja':0,'Media':1}
ypruebaT=[trans[item] for item in ypruebaT]
